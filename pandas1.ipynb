# %%
import pandas as pd

# %%
df = pd.read_csv('freetext_features.csv', delimiter='|')

# %%
df.head()
# Out:
#            UserID  DD.comma.space  UU.comma.space  H.comma  H.space  \
# 0  A1BU2A9JTH4X2S             119             143       96      120
# 1  A1BU2A9JTH4X2S             125             143      113      131
# 2  A1BU2A9JTH4X2S              78             115       90      127
# 3  A1BU2A9JTH4X2S              92             135       84      127
# 4  A1BU2A9JTH4X2S             102             138       95      131
#
#    DD.period.space  UU.period.space  H.period  H.space.1  DD.space.t  \
# 0              109               77       124         92         121
# 1               64               55       108         99         221
# 2              137              112       116         91         163
# 3              153              125       122         94         576
# 4              120               64       145         89         271
#
#    UU.space.t  H.space.2  H.t  DD.e.space  UU.e.space    H.e  H.space.3
# ...
